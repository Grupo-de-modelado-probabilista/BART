# %% [markdown]
# # Bikes with full dataset

# %%
import arviz as az
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import pymc as pm
import pymc_bart as pmb
from vi_evi import vi_evi

# %%
# %load_ext autoreload
# %autoreload 2

# %%
RANDOM_SEED = 8457
rng = np.random.RandomState(RANDOM_SEED)
az.style.use("arviz-white")
plt.rcParams["figure.dpi"] = 300

# %%
bikes = pd.read_csv("bikes_full.csv")

Y = bikes.pop("count")
X = bikes

# %% [markdown]
# We perform a first run to get the ranking of the variable importance.

# %%
with pm.Model() as model:
    α = pm.Exponential("α", 0.1)
    μ_ = pmb.BART("μ_", X, np.log(Y), m=50)
    μ = pm.Deterministic("μ", np.exp(μ_))
    y = pm.NegativeBinomial("y", mu=μ, alpha=α, observed=Y)
    idata_50 = pm.sample(
        chains=4, random_seed=RANDOM_SEED, compute_convergence_checks=False
    )
# Out:
# Multiprocess sampling (4 chains in 4 jobs)
# CompoundStep
# >NUTS: [α]
# >PGBART: [μ_]
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# Sampling 4 chains for 1_000 tune and 1_000 draw iterations (4_000 + 4_000 draws total) took 261 seconds.

# %%
vi_results_50 = pmb.compute_variable_importance(
    idata_50, μ_, X, method="VI", random_seed=RANDOM_SEED
)
bw_results_50 = pmb.compute_variable_importance(
    idata_50, μ_, X, method="backward", random_seed=RANDOM_SEED
)

# %%
_, axes = plt.subplots(1, 2, figsize=(12, 4))

pmb.plot_variable_importance(vi_results_50, figsize=(12, 5), ax=axes[0])
axes[0].set_title("VI")
axes[0].set_xticklabels(axes[0].get_xticklabels(), rotation=45, ha="right", fontsize=11)

pmb.plot_variable_importance(bw_results_50, figsize=(12, 5), ax=axes[1])
axes[1].set_title("backward")
axes[1].set_xticklabels(
    axes[1].get_xticklabels(), rotation=45, ha="right", fontsize=11
);

# %%
_, ax = pmb.plot_variable_inclusion(idata_50, X, figsize=(12, 5))
ax.set_title("Normalized variable inclusion", fontsize=16)
ax.set_xticklabels(ax.get_xticklabels(), rotation=45, ha="right", fontsize=12)
ax.set_yticklabels(ax.get_yticklabels(), rotation=45, ha="right", fontsize=11);
# Out:
# /var/folders/m_/brf3tky55f3gf6dy8w7c6s0w0000gn/T/ipykernel_11552/3566872728.py:4: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_yticklabels(ax.get_yticklabels(), rotation=45, ha="right", fontsize=11);

# %%
axes = pmb.plot_scatter_submodels(vi_results_50, np.exp, figsize=(12, 10), grid=(4, 3))
plt.suptitle("Comparison of submodels' predictions to full model's\n", fontsize=16)
plt.tight_layout();
# Out:
# /var/folders/m_/brf3tky55f3gf6dy8w7c6s0w0000gn/T/ipykernel_11552/3028070535.py:3: UserWarning: The figure layout has changed to tight
#   plt.tight_layout();

# %% [markdown]
# ## Explicit computation of R² following method="VI" order, with m=50

# %%
idatas_50 = []
bart_rvs_50 = []

for idx in range(X.shape[1]):
    with pm.Model() as model:
        α = pm.Exponential("α", 0.1)
        μ_ = pmb.BART(
            "μ_", X.iloc[:, vi_results_50["indices"][: idx + 1]], np.log(Y), m=50
        )
        μ = pm.Deterministic("μ", np.exp(μ_))
        y = pm.NegativeBinomial("y", mu=μ, alpha=α, observed=Y)
        idata = pm.sample(
            chains=4, random_seed=RANDOM_SEED, compute_convergence_checks=False
        )
        idatas_50.append(idata)
        bart_rvs_50.append(μ_)
# Out:
# Multiprocess sampling (4 chains in 4 jobs)
# CompoundStep
# >NUTS: [α]
# >PGBART: [μ_]
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# Sampling 4 chains for 1_000 tune and 1_000 draw iterations (4_000 + 4_000 draws total) took 253 seconds.
# Multiprocess sampling (4 chains in 4 jobs)
# CompoundStep
# >NUTS: [α]
# >PGBART: [μ_]
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# Sampling 4 chains for 1_000 tune and 1_000 draw iterations (4_000 + 4_000 draws total) took 264 seconds.
# Multiprocess sampling (4 chains in 4 jobs)
# CompoundStep
# >NUTS: [α]
# >PGBART: [μ_]
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# Sampling 4 chains for 1_000 tune and 1_000 draw iterations (4_000 + 4_000 draws total) took 285 seconds.
# Multiprocess sampling (4 chains in 4 jobs)
# CompoundStep
# >NUTS: [α]
# >PGBART: [μ_]
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# Sampling 4 chains for 1_000 tune and 1_000 draw iterations (4_000 + 4_000 draws total) took 309 seconds.
# Multiprocess sampling (4 chains in 4 jobs)
# CompoundStep
# >NUTS: [α]
# >PGBART: [μ_]
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# Sampling 4 chains for 1_000 tune and 1_000 draw iterations (4_000 + 4_000 draws total) took 286 seconds.
# Multiprocess sampling (4 chains in 4 jobs)
# CompoundStep
# >NUTS: [α]
# >PGBART: [μ_]
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# Sampling 4 chains for 1_000 tune and 1_000 draw iterations (4_000 + 4_000 draws total) took 293 seconds.
# Multiprocess sampling (4 chains in 4 jobs)
# CompoundStep
# >NUTS: [α]
# >PGBART: [μ_]
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# Sampling 4 chains for 1_000 tune and 1_000 draw iterations (4_000 + 4_000 draws total) took 286 seconds.
# Multiprocess sampling (4 chains in 4 jobs)
# CompoundStep
# >NUTS: [α]
# >PGBART: [μ_]
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# Sampling 4 chains for 1_000 tune and 1_000 draw iterations (4_000 + 4_000 draws total) took 296 seconds.
# Multiprocess sampling (4 chains in 4 jobs)
# CompoundStep
# >NUTS: [α]
# >PGBART: [μ_]
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# Sampling 4 chains for 1_000 tune and 1_000 draw iterations (4_000 + 4_000 draws total) took 294 seconds.
# Multiprocess sampling (4 chains in 4 jobs)
# CompoundStep
# >NUTS: [α]
# >PGBART: [μ_]
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# Sampling 4 chains for 1_000 tune and 1_000 draw iterations (4_000 + 4_000 draws total) took 309 seconds.
# Multiprocess sampling (4 chains in 4 jobs)
# CompoundStep
# >NUTS: [α]
# >PGBART: [μ_]
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# Sampling 4 chains for 1_000 tune and 1_000 draw iterations (4_000 + 4_000 draws total) took 285 seconds.

# %% [markdown]
# We now check that computing the predictions estimated by pruning the trees is close to the predictions if we actually ommits covariables and refit models.

# %%
ax = vi_evi(
    bart_rvs_50,
    idatas_50,
    X,
    vi_results_50["indices"],
    "VI",
    100,
    RANDOM_SEED,
    figsize=(10, 5),
)
ax.set_title("Bikes, m=50, method=VI")
plt.savefig("bikes_m50_vi_full.png");

# %%
# Free memory
del idatas
del bart_rvs

# %% [markdown]
# ## Explicit computation of R² following method="backward" order, with m=50

# %%
idatas_50 = []
bart_rvs_50 = []

for idx in range(X.shape[1]):
    with pm.Model() as model:
        α = pm.Exponential("α", 0.1)
        μ_ = pmb.BART(
            "μ_", X.iloc[:, bw_results_50["indices"][: idx + 1]], np.log(Y), m=50
        )
        μ = pm.Deterministic("μ", np.exp(μ_))
        y = pm.NegativeBinomial("y", mu=μ, alpha=α, observed=Y)
        idata = pm.sample(
            chains=4, random_seed=RANDOM_SEED, compute_convergence_checks=False
        )
        idatas_50.append(idata)
        bart_rvs_50.append(μ_)
# Out:
# Multiprocess sampling (4 chains in 4 jobs)
# CompoundStep
# >NUTS: [α]
# >PGBART: [μ_]
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# Sampling 4 chains for 1_000 tune and 1_000 draw iterations (4_000 + 4_000 draws total) took 274 seconds.
# Multiprocess sampling (4 chains in 4 jobs)
# CompoundStep
# >NUTS: [α]
# >PGBART: [μ_]
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# Sampling 4 chains for 1_000 tune and 1_000 draw iterations (4_000 + 4_000 draws total) took 271 seconds.
# Multiprocess sampling (4 chains in 4 jobs)
# CompoundStep
# >NUTS: [α]
# >PGBART: [μ_]
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# Sampling 4 chains for 1_000 tune and 1_000 draw iterations (4_000 + 4_000 draws total) took 271 seconds.
# Multiprocess sampling (4 chains in 4 jobs)
# CompoundStep
# >NUTS: [α]
# >PGBART: [μ_]
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# Sampling 4 chains for 1_000 tune and 1_000 draw iterations (4_000 + 4_000 draws total) took 271 seconds.
# Multiprocess sampling (4 chains in 4 jobs)
# CompoundStep
# >NUTS: [α]
# >PGBART: [μ_]
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# Sampling 4 chains for 1_000 tune and 1_000 draw iterations (4_000 + 4_000 draws total) took 283 seconds.
# Multiprocess sampling (4 chains in 4 jobs)
# CompoundStep
# >NUTS: [α]
# >PGBART: [μ_]
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# Sampling 4 chains for 1_000 tune and 1_000 draw iterations (4_000 + 4_000 draws total) took 274 seconds.
# Multiprocess sampling (4 chains in 4 jobs)
# CompoundStep
# >NUTS: [α]
# >PGBART: [μ_]
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# Sampling 4 chains for 1_000 tune and 1_000 draw iterations (4_000 + 4_000 draws total) took 278 seconds.
# Multiprocess sampling (4 chains in 4 jobs)
# CompoundStep
# >NUTS: [α]
# >PGBART: [μ_]
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# Sampling 4 chains for 1_000 tune and 1_000 draw iterations (4_000 + 4_000 draws total) took 275 seconds.
# Multiprocess sampling (4 chains in 4 jobs)
# CompoundStep
# >NUTS: [α]
# >PGBART: [μ_]
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# Sampling 4 chains for 1_000 tune and 1_000 draw iterations (4_000 + 4_000 draws total) took 278 seconds.
# Multiprocess sampling (4 chains in 4 jobs)
# CompoundStep
# >NUTS: [α]
# >PGBART: [μ_]
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# Sampling 4 chains for 1_000 tune and 1_000 draw iterations (4_000 + 4_000 draws total) took 285 seconds.
# Multiprocess sampling (4 chains in 4 jobs)
# CompoundStep
# >NUTS: [α]
# >PGBART: [μ_]
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# Sampling 4 chains for 1_000 tune and 1_000 draw iterations (4_000 + 4_000 draws total) took 283 seconds.

# %%
ax = vi_evi(
    bart_rvs_50,
    idatas_50,
    X,
    bw_results_50["indices"],
    "backward",
    100,
    RANDOM_SEED,
    figsize=(10, 5),
)
ax.set_title("Bikes, m=50, method=backward")
plt.savefig("bikes_m50_bw_full.png");

# %% [markdown]
# ## Explicit computation of R² following method="VI" order, with m=200

# %% [markdown]
# First run to get the ranking of the variable importance.

# %%
with pm.Model() as model:
    α = pm.Exponential("α", 0.1)
    μ_ = pmb.BART("μ_", X, np.log(Y), m=200)
    μ = pm.Deterministic("μ", np.exp(μ_))
    y = pm.NegativeBinomial("y", mu=μ, alpha=α, observed=Y)
    idata_200 = pm.sample(
        chains=4, random_seed=RANDOM_SEED, compute_convergence_checks=False
    )
# Out:
# Multiprocess sampling (4 chains in 4 jobs)
# CompoundStep
# >NUTS: [α]
# >PGBART: [μ_]
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# Sampling 4 chains for 1_000 tune and 1_000 draw iterations (4_000 + 4_000 draws total) took 1083 seconds.

# %%
vi_results_200 = pmb.compute_variable_importance(
    idata_200, μ_, X, method="VI", random_seed=RANDOM_SEED
)
bw_results_200 = pmb.compute_variable_importance(
    idata_200, μ_, X, method="backward", random_seed=RANDOM_SEED
)

# %%
_, axes = plt.subplots(1, 2, figsize=(12, 4))

pmb.plot_variable_importance(vi_results_200, figsize=(12, 5), ax=axes[0])
axes[0].set_title("VI")
axes[0].set_xticklabels(axes[0].get_xticklabels(), rotation=45, ha="right", fontsize=11)

pmb.plot_variable_importance(bw_results_200, figsize=(12, 5), ax=axes[1])
axes[1].set_title("backward")
axes[1].set_xticklabels(
    axes[1].get_xticklabels(), rotation=45, ha="right", fontsize=11
);

# %%
_, ax = pmb.plot_variable_inclusion(idata_200, X, figsize=(12, 5))
ax.set_title("Normalized variable inclusion", fontsize=16)
ax.set_xticklabels(ax.get_xticklabels(), rotation=45, ha="right", fontsize=12)
ax.set_yticklabels(ax.get_yticklabels(), rotation=45, ha="right", fontsize=11);
# Out:
# /var/folders/m_/brf3tky55f3gf6dy8w7c6s0w0000gn/T/ipykernel_11552/4157930357.py:4: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_yticklabels(ax.get_yticklabels(), rotation=45, ha="right", fontsize=11);

# %%
axes = pmb.plot_scatter_submodels(vi_results_200, np.exp, figsize=(12, 10), grid=(4, 3))
plt.suptitle("Comparison of submodels' predictions to full model's", fontsize=16)
plt.tight_layout();
# Out:
# /var/folders/m_/brf3tky55f3gf6dy8w7c6s0w0000gn/T/ipykernel_11552/724910099.py:3: UserWarning: The figure layout has changed to tight
#   plt.tight_layout();

# %%
idatas_200 = []
bart_rvs_200 = []

for idx in range(X.shape[1]):
    with pm.Model() as model:
        α = pm.Exponential("α", 0.1)
        μ_ = pmb.BART(
            "μ_", X.iloc[:, vi_results_200["indices"][: idx + 1]], np.log(Y), m=200
        )
        μ = pm.Deterministic("μ", np.exp(μ_))
        y = pm.NegativeBinomial("y", mu=μ, alpha=α, observed=Y)
        idata = pm.sample(
            chains=4, random_seed=RANDOM_SEED, compute_convergence_checks=False
        )
        idatas_200.append(idata)
        bart_rvs_200.append(μ_)
# Out:
# Multiprocess sampling (4 chains in 4 jobs)
# CompoundStep
# >NUTS: [α]
# >PGBART: [μ_]
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# Sampling 4 chains for 1_000 tune and 1_000 draw iterations (4_000 + 4_000 draws total) took 1109 seconds.
# Multiprocess sampling (4 chains in 4 jobs)
# CompoundStep
# >NUTS: [α]
# >PGBART: [μ_]
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# Sampling 4 chains for 1_000 tune and 1_000 draw iterations (4_000 + 4_000 draws total) took 1190 seconds.
# Multiprocess sampling (4 chains in 4 jobs)
# CompoundStep
# >NUTS: [α]
# >PGBART: [μ_]
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# Sampling 4 chains for 1_000 tune and 1_000 draw iterations (4_000 + 4_000 draws total) took 1137 seconds.
# Multiprocess sampling (4 chains in 4 jobs)
# CompoundStep
# >NUTS: [α]
# >PGBART: [μ_]
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# Sampling 4 chains for 1_000 tune and 1_000 draw iterations (4_000 + 4_000 draws total) took 1239 seconds.
# Multiprocess sampling (4 chains in 4 jobs)
# CompoundStep
# >NUTS: [α]
# >PGBART: [μ_]
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# Sampling 4 chains for 1_000 tune and 1_000 draw iterations (4_000 + 4_000 draws total) took 1317 seconds.
# Multiprocess sampling (4 chains in 4 jobs)
# CompoundStep
# >NUTS: [α]
# >PGBART: [μ_]
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# Sampling 4 chains for 1_000 tune and 1_000 draw iterations (4_000 + 4_000 draws total) took 1246 seconds.
# Multiprocess sampling (4 chains in 4 jobs)
# CompoundStep
# >NUTS: [α]
# >PGBART: [μ_]
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# Sampling 4 chains for 1_000 tune and 1_000 draw iterations (4_000 + 4_000 draws total) took 1252 seconds.
# Multiprocess sampling (4 chains in 4 jobs)
# CompoundStep
# >NUTS: [α]
# >PGBART: [μ_]
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# Sampling 4 chains for 1_000 tune and 1_000 draw iterations (4_000 + 4_000 draws total) took 1307 seconds.
# Multiprocess sampling (4 chains in 4 jobs)
# CompoundStep
# >NUTS: [α]
# >PGBART: [μ_]
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# Sampling 4 chains for 1_000 tune and 1_000 draw iterations (4_000 + 4_000 draws total) took 1392 seconds.
# python(19541) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Multiprocess sampling (4 chains in 4 jobs)
# CompoundStep
# >NUTS: [α]
# >PGBART: [μ_]
# python(19543) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(19544) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(19545) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Output()
# python(19546) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# Sampling 4 chains for 1_000 tune and 435 draw iterations (4_000 + 1_740 draws total) took 979 seconds.
# python(20002) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Multiprocess sampling (4 chains in 4 jobs)
# CompoundStep
# >NUTS: [α]
# >PGBART: [μ_]
# python(20009) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(20010) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(20011) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Output()
# python(20012) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.

# %%
ax = vi_evi(
    bart_rvs_200,
    idatas_200,
    X,
    vi_results_200["indices"],
    "VI",
    100,
    RANDOM_SEED,
    figsize=(10, 5),
)
ax.set_title("Bikes, m=200, method=VI")
plt.savefig("bikes_m200_vi_full.png")

# %% [markdown]
# ## Explicit computation of R² following method="backward" order, with m=200

# %%
idatas_200 = []
bart_rvs_200 = []

for idx in range(X.shape[1]):
    with pm.Model() as model:
        α = pm.Exponential("α", 0.1)
        μ_ = pmb.BART(
            "μ_", X.iloc[:, bw_results_200["indices"][: idx + 1]], np.log(Y), m=200
        )
        μ = pm.Deterministic("μ", np.exp(μ_))
        y = pm.NegativeBinomial("y", mu=μ, alpha=α, observed=Y)
        idata = pm.sample(
            chains=4, random_seed=RANDOM_SEED, compute_convergence_checks=False
        )
        idatas_200.append(idata)
        bart_rvs_200.append(μ_)
# Out:
# Multiprocess sampling (4 chains in 4 jobs)
# CompoundStep
# >NUTS: [α]
# >PGBART: [μ_]
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
#     <div>
#       <progress value='8000' class='' max='8000' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [8000/8000 21:50&lt;00:00 Sampling 4 chains, 0 divergences]
#     </div>
# Sampling 4 chains for 1_000 tune and 1_000 draw iterations (4_000 + 4_000 draws total) took 1311 seconds.
# Multiprocess sampling (4 chains in 4 jobs)
# CompoundStep
# >NUTS: [α]
# >PGBART: [μ_]
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
#     <div>
#       <progress value='8000' class='' max='8000' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [8000/8000 21:46&lt;00:00 Sampling 4 chains, 0 divergences]
#     </div>
# Sampling 4 chains for 1_000 tune and 1_000 draw iterations (4_000 + 4_000 draws total) took 1307 seconds.
# Multiprocess sampling (4 chains in 4 jobs)
# CompoundStep
# >NUTS: [α]
# >PGBART: [μ_]
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
#     <div>
#       <progress value='8000' class='' max='8000' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [8000/8000 21:47&lt;00:00 Sampling 4 chains, 0 divergences]
#     </div>
# Sampling 4 chains for 1_000 tune and 1_000 draw iterations (4_000 + 4_000 draws total) took 1308 seconds.
# Multiprocess sampling (4 chains in 4 jobs)
# CompoundStep
# >NUTS: [α]
# >PGBART: [μ_]
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
#     <div>
#       <progress value='8000' class='' max='8000' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [8000/8000 22:02&lt;00:00 Sampling 4 chains, 0 divergences]
#     </div>
# Sampling 4 chains for 1_000 tune and 1_000 draw iterations (4_000 + 4_000 draws total) took 1323 seconds.
# Multiprocess sampling (4 chains in 4 jobs)
# CompoundStep
# >NUTS: [α]
# >PGBART: [μ_]
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
#     <div>
#       <progress value='8000' class='' max='8000' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [8000/8000 21:57&lt;00:00 Sampling 4 chains, 0 divergences]
#     </div>
# Sampling 4 chains for 1_000 tune and 1_000 draw iterations (4_000 + 4_000 draws total) took 1317 seconds.
# Multiprocess sampling (4 chains in 4 jobs)
# CompoundStep
# >NUTS: [α]
# >PGBART: [μ_]
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
#     <div>
#       <progress value='8000' class='' max='8000' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [8000/8000 22:12&lt;00:00 Sampling 4 chains, 0 divergences]
#     </div>
# Sampling 4 chains for 1_000 tune and 1_000 draw iterations (4_000 + 4_000 draws total) took 1332 seconds.
# Multiprocess sampling (4 chains in 4 jobs)
# CompoundStep
# >NUTS: [α]
# >PGBART: [μ_]
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
#     <div>
#       <progress value='8000' class='' max='8000' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [8000/8000 22:16&lt;00:00 Sampling 4 chains, 0 divergences]
#     </div>
# Sampling 4 chains for 1_000 tune and 1_000 draw iterations (4_000 + 4_000 draws total) took 1336 seconds.
# Multiprocess sampling (4 chains in 4 jobs)
# CompoundStep
# >NUTS: [α]
# >PGBART: [μ_]
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
#     <div>
#       <progress value='8000' class='' max='8000' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [8000/8000 22:23&lt;00:00 Sampling 4 chains, 0 divergences]
#     </div>
# Sampling 4 chains for 1_000 tune and 1_000 draw iterations (4_000 + 4_000 draws total) took 1343 seconds.
# Multiprocess sampling (4 chains in 4 jobs)
# CompoundStep
# >NUTS: [α]
# >PGBART: [μ_]
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
#     <div>
#       <progress value='8000' class='' max='8000' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [8000/8000 22:10&lt;00:00 Sampling 4 chains, 0 divergences]
#     </div>
# Sampling 4 chains for 1_000 tune and 1_000 draw iterations (4_000 + 4_000 draws total) took 1331 seconds.
# Multiprocess sampling (4 chains in 4 jobs)
# CompoundStep
# >NUTS: [α]
# >PGBART: [μ_]
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
#     <div>
#       <progress value='8000' class='' max='8000' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [8000/8000 22:27&lt;00:00 Sampling 4 chains, 0 divergences]
#     </div>
# Sampling 4 chains for 1_000 tune and 1_000 draw iterations (4_000 + 4_000 draws total) took 1347 seconds.
# Multiprocess sampling (4 chains in 4 jobs)
# CompoundStep
# >NUTS: [α]
# >PGBART: [μ_]
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
#     <div>
#       <progress value='8000' class='' max='8000' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [8000/8000 22:21&lt;00:00 Sampling 4 chains, 0 divergences]
#     </div>
# Sampling 4 chains for 1_000 tune and 1_000 draw iterations (4_000 + 4_000 draws total) took 1341 seconds.

# %%
ax = vi_evi(
    bart_rvs_200,
    idatas_200,
    X,
    bw_results_200["indices"],
    "backward",
    100,
    RANDOM_SEED,
    figsize=(10, 5),
)
ax.set_title("Bikes, m=200, method=backward")
plt.savefig("bikes_m200_bw_full.png");
