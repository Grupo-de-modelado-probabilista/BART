# %% [markdown]
# # Body fat full dataset

# %%
import arviz as az
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import pymc as pm
import pymc_bart as pmb
from vi_evi import vi_evi

# %%
RANDOM_SEED = 8457
rng = np.random.RandomState(RANDOM_SEED)
az.style.use("arviz-white")
plt.rcParams["figure.dpi"] = 300

# %%
body_fat = pd.read_csv("body_fat_full.csv")

Y = body_fat.pop("siri")
X = body_fat

# %%
Y.describe()
# Out:
# count    251.000000
# mean      19.086853
# std        8.323554
# min        0.000000
# 25%       12.450000
# 50%       19.200000
# 75%       25.250000
# max       47.500000
# Name: siri, dtype: float64

# %% [markdown]
# We perform a first run to get the ranking of the variable importance.

# %%
with pm.Model() as model:
    μ = pmb.BART("μ", X, Y)
    σ = pm.HalfNormal("σ", 1)
    y = pm.Normal("y", μ, σ, observed=Y)
    idata_50 = pm.sample(
        chains=4,
        compute_convergence_checks=False,
        random_seed=RANDOM_SEED,
    )
# Out:
# Multiprocess sampling (4 chains in 4 jobs)
# CompoundStep
# >PGBART: [μ]
# >NUTS: [σ]
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# Sampling 4 chains for 1_000 tune and 1_000 draw iterations (4_000 + 4_000 draws total) took 21 seconds.

# %%
vi_results_50 = pmb.compute_variable_importance(
    idata_50, μ, X, method="VI", random_seed=RANDOM_SEED
)
bw_results_50 = pmb.compute_variable_importance(
    idata_50, μ, X, method="backward", random_seed=RANDOM_SEED
)

# %%
_, axes = plt.subplots(1, 2, figsize=(12, 4))

pmb.plot_variable_importance(vi_results_50, figsize=(12, 5), ax=axes[0])
axes[0].set_title("VI")
axes[0].set_xticklabels(axes[0].get_xticklabels(), rotation=45, ha="right", fontsize=11)

pmb.plot_variable_importance(bw_results_50, figsize=(12, 5), ax=axes[1])
axes[1].set_title("backward")
axes[1].set_xticklabels(
    axes[1].get_xticklabels(), rotation=45, ha="right", fontsize=11
);

# %%
_, ax = pmb.plot_variable_inclusion(idata_50, X, figsize=(12, 5))
ax.set_title("Normalized variable inclusion", fontsize=16)
ax.set_xticklabels(ax.get_xticklabels(), rotation=45, ha="right", fontsize=12)
ax.set_yticklabels(ax.get_yticklabels(), rotation=45, ha="right", fontsize=11);
# Out:
# /var/folders/m_/brf3tky55f3gf6dy8w7c6s0w0000gn/T/ipykernel_32003/3566872728.py:4: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_yticklabels(ax.get_yticklabels(), rotation=45, ha="right", fontsize=11);

# %%
axes = pmb.plot_scatter_submodels(vi_results_50, figsize=(12, 12), grid=(5, 3))
plt.suptitle("Comparison of submodels' predictions to full model's\n", fontsize=16)
plt.tight_layout();
# Out:
# /var/folders/m_/brf3tky55f3gf6dy8w7c6s0w0000gn/T/ipykernel_32003/3234596168.py:3: UserWarning: The figure layout has changed to tight
#   plt.tight_layout();

# %% [markdown]
# ## Explicit computation of R² following method="VI" order, with m=50

# %%
idatas_50 = []
bart_rvs_50 = []

for idx in range(X.shape[1]):
    with pm.Model() as model:
        μ = pmb.BART("μ", X.iloc[:, vi_results_50["indices"][: idx + 1]], Y, m=50)
        σ = pm.HalfNormal("σ", 1)
        y = pm.Normal("y", μ, σ, observed=Y)
        idata = pm.sample(
            chains=4, random_seed=RANDOM_SEED, compute_convergence_checks=False
        )
        idatas_50.append(idata)
        bart_rvs_50.append(μ)
# Out:
# Multiprocess sampling (4 chains in 4 jobs)
# CompoundStep
# >PGBART: [μ]
# >NUTS: [σ]
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# Sampling 4 chains for 1_000 tune and 1_000 draw iterations (4_000 + 4_000 draws total) took 20 seconds.
# Multiprocess sampling (4 chains in 4 jobs)
# CompoundStep
# >PGBART: [μ]
# >NUTS: [σ]
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# Sampling 4 chains for 1_000 tune and 1_000 draw iterations (4_000 + 4_000 draws total) took 20 seconds.
# Multiprocess sampling (4 chains in 4 jobs)
# CompoundStep
# >PGBART: [μ]
# >NUTS: [σ]
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# ...

# %%
ax = vi_evi(
    bart_rvs_50,
    idatas_50,
    X,
    vi_results_50["indices"],
    "VI",
    100,
    RANDOM_SEED,
    figsize=(10, 5),
)
ax.set_title("Body fat, m=50, method=VI")
plt.savefig("body_fat_m50_vi.png");

# %% [markdown]
# ## Explicit computation of R² following method="backward" order, with m=50

# %%
idatas_50 = []
bart_rvs_50 = []

for idx in range(X.shape[1]):
    with pm.Model() as model:
        μ = pmb.BART("μ", X.iloc[:, bw_results_50["indices"][: idx + 1]], Y, m=50)
        σ = pm.HalfNormal("σ", 1)
        y = pm.Normal("y", μ, σ, observed=Y)
        idata = pm.sample(
            chains=4, random_seed=RANDOM_SEED, compute_convergence_checks=False
        )
        idatas_50.append(idata)
        bart_rvs_50.append(μ)
# Out:
# Multiprocess sampling (4 chains in 4 jobs)
# CompoundStep
# >PGBART: [μ]
# >NUTS: [σ]
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# Sampling 4 chains for 1_000 tune and 1_000 draw iterations (4_000 + 4_000 draws total) took 24 seconds.
# Multiprocess sampling (4 chains in 4 jobs)
# CompoundStep
# >PGBART: [μ]
# >NUTS: [σ]
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# Sampling 4 chains for 1_000 tune and 1_000 draw iterations (4_000 + 4_000 draws total) took 23 seconds.
# Multiprocess sampling (4 chains in 4 jobs)
# CompoundStep
# >PGBART: [μ]
# >NUTS: [σ]
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# ...

# %%
ax = vi_evi(
    bart_rvs_50,
    idatas_50,
    X,
    bw_results_50["indices"],
    "backward",
    100,
    RANDOM_SEED,
    figsize=(10, 5),
)
ax.set_title("Body fat, m=50, method=backward")
plt.savefig("body_fat_m50_bw.png");

# %% [markdown]
# ## Explicit computation of R² following method="VI" order, with m=200

# %% [markdown]
# First run to get the ranking of the variable importance.

# %%
# clean memory
del idatas_50
del bart_rvs_50
del idata
del idata_50

# %%
with pm.Model() as model:
    μ = pmb.BART("μ", X, Y, m=200)
    σ = pm.HalfNormal("σ", 1)
    y = pm.Normal("y", μ, σ, observed=Y)
    idata_200 = pm.sample(
        chains=4, random_seed=RANDOM_SEED, compute_convergence_checks=False
    )
# Out:
# Multiprocess sampling (4 chains in 4 jobs)
# CompoundStep
# >PGBART: [μ]
# >NUTS: [σ]
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# Sampling 4 chains for 1_000 tune and 1_000 draw iterations (4_000 + 4_000 draws total) took 91 seconds.

# %%
vi_results_200 = pmb.compute_variable_importance(
    idata_200, μ, X, method="VI", random_seed=RANDOM_SEED
)
bw_results_200 = pmb.compute_variable_importance(
    idata_200, μ, X, method="backward", random_seed=RANDOM_SEED
)

# %%
_, axes = plt.subplots(1, 2, figsize=(12, 4))

pmb.plot_variable_importance(vi_results_200, figsize=(12, 5), ax=axes[0])
axes[0].set_title("VI")
axes[0].set_xticklabels(axes[0].get_xticklabels(), rotation=45, ha="right", fontsize=11)

pmb.plot_variable_importance(bw_results_200, figsize=(12, 5), ax=axes[1])
axes[1].set_title("backward")
axes[1].set_xticklabels(
    axes[1].get_xticklabels(), rotation=45, ha="right", fontsize=11
);

# %%
_, ax = pmb.plot_variable_inclusion(idata_200, X, figsize=(12, 5))
ax.set_title("Normalized variable inclusion", fontsize=16)
ax.set_xticklabels(ax.get_xticklabels(), rotation=45, ha="right", fontsize=12)
ax.set_yticklabels(ax.get_yticklabels(), rotation=45, ha="right", fontsize=11);
# Out:
# /var/folders/m_/brf3tky55f3gf6dy8w7c6s0w0000gn/T/ipykernel_32003/4157930357.py:4: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_yticklabels(ax.get_yticklabels(), rotation=45, ha="right", fontsize=11);

# %%
axes = pmb.plot_scatter_submodels(vi_results_200, figsize=(12, 12), grid=(5, 3))
plt.suptitle("Comparison of submodels' predictions to full model's", fontsize=16)
plt.tight_layout();
# Out:
# /var/folders/m_/brf3tky55f3gf6dy8w7c6s0w0000gn/T/ipykernel_32003/557614568.py:3: UserWarning: The figure layout has changed to tight
#   plt.tight_layout();

# %%
idatas_200 = []
bart_rvs_200 = []

for idx in range(X.shape[1]):
    with pm.Model() as model:
        μ = pmb.BART("μ", X.iloc[:, vi_results_200["indices"][: idx + 1]], Y, m=200)
        σ = pm.HalfNormal("σ", 1)
        y = pm.Normal("y", μ, σ, observed=Y)
        idata = pm.sample(
            chains=4, random_seed=RANDOM_SEED, compute_convergence_checks=False
        )
        idatas_200.append(idata)
        bart_rvs_200.append(μ)
    # clean memory
    del (μ, σ, y, idata)
# Out:
# Multiprocess sampling (4 chains in 4 jobs)
# CompoundStep
# >PGBART: [μ]
# >NUTS: [σ]
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# Sampling 4 chains for 1_000 tune and 1_000 draw iterations (4_000 + 4_000 draws total) took 99 seconds.
# Multiprocess sampling (4 chains in 4 jobs)
# CompoundStep
# >PGBART: [μ]
# >NUTS: [σ]
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# Sampling 4 chains for 1_000 tune and 1_000 draw iterations (4_000 + 4_000 draws total) took 191 seconds.
# Multiprocess sampling (4 chains in 4 jobs)
# CompoundStep
# >PGBART: [μ]
# >NUTS: [σ]
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# ...

# %%
ax = vi_evi(
    bart_rvs_200,
    idatas_200,
    X,
    vi_results_200["indices"],
    "VI",
    100,
    RANDOM_SEED,
    figsize=(10, 5),
)
ax.set_title("Body fat, m=200, method=VI")
plt.savefig("body_fat_m200_vi.png")

# %%
# clean memory
del idata_200
del idatas_200
del bart_rvs_200

# %% [markdown]
# ## Explicit computation of R² following method="backward" order, with m=200

# %%
idatas_200 = []
bart_rvs_200 = []

for idx in range(X.shape[1]):
    with pm.Model() as model:
        μ = pmb.BART("μ", X.iloc[:, bw_results_200["indices"][: idx + 1]], Y, m=200)
        σ = pm.HalfNormal("σ", 1)
        y = pm.Normal("y", μ, σ, observed=Y)
        idata = pm.sample(
            chains=4, random_seed=RANDOM_SEED, compute_convergence_checks=False
        )
        idatas_200.append(idata)
        bart_rvs_200.append(μ)
    # clean memory
    del (μ, σ, y, idata)
# Out:
# Multiprocess sampling (4 chains in 4 jobs)
# CompoundStep
# >PGBART: [μ]
# >NUTS: [σ]
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# Sampling 4 chains for 1_000 tune and 1_000 draw iterations (4_000 + 4_000 draws total) took 79 seconds.
# Multiprocess sampling (4 chains in 4 jobs)
# CompoundStep
# >PGBART: [μ]
# >NUTS: [σ]
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# Sampling 4 chains for 1_000 tune and 1_000 draw iterations (4_000 + 4_000 draws total) took 78 seconds.
# Multiprocess sampling (4 chains in 4 jobs)
# CompoundStep
# >PGBART: [μ]
# >NUTS: [σ]
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# ...

# %%
ax = vi_evi(
    bart_rvs_200,
    idatas_200,
    X,
    bw_results_200["indices"],
    "backward",
    100,
    RANDOM_SEED,
    figsize=(10, 5),
)
ax.set_title("Body fat, m=200, method=backward")
plt.savefig("body_fat_m200_bw.png")
