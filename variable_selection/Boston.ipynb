# %% [markdown]
# # Boston housing values

# %%
import warnings

import arviz as az
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import pymc as pm
import pymc_bart as pmb
from vi_evi import vi_evi

warnings.simplefilter(action="ignore", category=FutureWarning)

# %%
RANDOM_SEED = 8457
rng = np.random.RandomState(RANDOM_SEED)
az.style.use("arviz-white")
plt.rcParams["figure.dpi"] = 300

# %% [markdown]
# ### Load original Boston housing dataset

# %%
boston = pd.read_csv("Boston.csv")

# %%
boston.describe()
# Out:
#              crim          zn       indus        chas         nox          rm  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean     4.673727   11.363636   11.136779    0.069170  465.069952    6.284634
# std     25.223207   23.322453    6.860353    0.253994  222.311286    0.702617
# min      0.006320    0.000000    0.460000    0.000000    0.400000    3.561000
# 25%      0.082045    0.000000    5.190000    0.000000  429.000000    5.885500
# 50%      0.256510    0.000000    9.690000    0.000000  504.000000    6.208500
# 75%      3.689388   12.500000   18.100000    0.000000  605.000000    6.623500
# max    537.000000  100.000000   27.740000    1.000000  871.000000    8.780000
#
#               age         dis         rad         tax     ptratio       black  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean    68.574901    3.795043    9.549407  408.237154   18.455534  356.674032
# std     28.148861    2.105710    8.707259  168.537116    2.164946   91.294864
# min      2.900000    1.129600    1.000000  187.000000   12.600000    0.320000
# 25%     45.025000    2.100175    4.000000  279.000000   17.400000  375.377500
# 50%     77.500000    3.207450    5.000000  330.000000   19.050000  391.440000
# 75%     94.075000    5.188425   24.000000  666.000000   20.200000  396.225000
# max    100.000000   12.126500   24.000000  711.000000   22.000000  396.900000
#
#             lstat        medv
# count  506.000000  506.000000
# mean    12.653063   22.532806
# std      7.141062    9.197104
# min      1.730000    5.000000
# 25%      6.950000   17.025000
# 50%     11.360000   21.200000
# 75%     16.955000   25.000000
# max     37.970000   50.000000

# %%
X = boston[
    [
        "crim",
        "zn",
        "indus",
        "chas",
        "nox",
        "rm",
        "age",
        "dis",
        "rad",
        "tax",
        "ptratio",
        "black",
        "lstat",
    ]
]
Y = boston["medv"]

# %%
Y.head()
# Out:
# 0    24.0
# 1    21.6
# 2    34.7
# 3    33.4
# 4    36.2
# Name: medv, dtype: float64

# %%
X.head()
# Out:
#       crim    zn  indus  chas    nox     rm   age     dis  rad  tax  ptratio  \
# 0  0.00632  18.0   2.31     0  538.0  6.575  65.2  4.0900    1  296     15.3
# 1  0.02731   0.0   7.07     0  469.0  6.421  78.9  4.9671    2  242     17.8
# 2  0.02729   0.0   7.07     0  469.0  7.185  61.1  4.9671    2  242     17.8
# 3  0.03237   0.0   2.18     0  458.0  6.998  45.8  6.0622    3  222     18.7
# 4  0.06905   0.0   2.18     0  458.0  7.147  54.2  6.0622    3  222     18.7
#
#     black  lstat
# 0  396.90   4.98
# 1  396.90   9.14
# 2  392.83   4.03
# 3  394.63   2.94
# 4  396.90   5.33

# %%
with pm.Model() as model:
    α = pm.Exponential("α", 0.1)
    μ_ = pmb.BART("μ_", X, np.log(Y), m=50)
    μ = pm.Deterministic("μ", np.exp(μ_))
    y = pm.NegativeBinomial("y", mu=μ, alpha=α, observed=Y)
    idata_50 = pm.sample(
        chains=4,
        random_seed=RANDOM_SEED,
    )
# Out:
# Multiprocess sampling (4 chains in 4 jobs)
# CompoundStep
# >NUTS: [α]
# >PGBART: [μ_]
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# Sampling 4 chains for 1_000 tune and 1_000 draw iterations (4_000 + 4_000 draws total) took 27 seconds.
# The rhat statistic is larger than 1.01 for some parameters. This indicates problems during sampling. See https://arxiv.org/abs/1903.08008 for details
# The effective sample size per chain is smaller than 100 for some parameters.  A higher number is needed for reliable rhat and ess computation. See https://arxiv.org/abs/1903.08008 for details

# %%
vi_results_50 = pmb.compute_variable_importance(
    idata_50, μ_, X, method="VI", random_seed=RANDOM_SEED
)
bw_results_50 = pmb.compute_variable_importance(
    idata_50, μ_, X, method="backward", random_seed=RANDOM_SEED
)

# %%
_, axes = plt.subplots(1, 2, figsize=(12, 4))

pmb.plot_variable_importance(vi_results_50, figsize=(12, 5), ax=axes[0])
axes[0].set_title("VI")
axes[0].set_xticklabels(axes[0].get_xticklabels(), rotation=45, ha="right", fontsize=11)

pmb.plot_variable_importance(bw_results_50, figsize=(12, 5), ax=axes[1])
axes[1].set_title("backward")
axes[1].set_xticklabels(
    axes[1].get_xticklabels(), rotation=45, ha="right", fontsize=11
);

# %%
_, ax = pmb.plot_variable_inclusion(idata_50, X, figsize=(12, 5))
ax.set_title("Normalized variable inclusion", fontsize=16)
ax.set_xticklabels(ax.get_xticklabels(), rotation=45, ha="right", fontsize=12)
ax.set_yticklabels(ax.get_yticklabels(), rotation=45, ha="right", fontsize=11);
# Out:
# /var/folders/m_/brf3tky55f3gf6dy8w7c6s0w0000gn/T/ipykernel_22826/3566872728.py:4: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_yticklabels(ax.get_yticklabels(), rotation=45, ha="right", fontsize=11);

# %%
axes = pmb.plot_scatter_submodels(vi_results_50, np.exp, figsize=(12, 10), grid=(4, 3))
plt.suptitle("Comparison of submodels' predictions to full model's\n", fontsize=16)
plt.tight_layout();
# Out:
# /Users/alex_andorra/mambaforge/envs/bart-variables/lib/python3.10/site-packages/pymc_bart/utils.py:519: UserWarning: The grid is smaller than the number of available variables to plot.
#                 Automatically adjusting the grid size.
#   warnings.warn(
# /var/folders/m_/brf3tky55f3gf6dy8w7c6s0w0000gn/T/ipykernel_22826/3028070535.py:3: UserWarning: The figure layout has changed to tight
#   plt.tight_layout();

# %% [markdown]
# ## Explicit computation of R² following method="VI" order, with m=50

# %%
idatas_50 = []
bart_rvs_50 = []

for idx in range(X.shape[1]):
    with pm.Model() as model:
        α = pm.Exponential("α", 0.1)
        μ_ = pmb.BART(
            "μ_", X.iloc[:, vi_results_50["indices"][: idx + 1]], np.log(Y), m=50
        )
        μ = pm.Deterministic("μ", np.exp(μ_))
        y = pm.NegativeBinomial("y", mu=μ, alpha=α, observed=Y)
        idata = pm.sample(
            chains=4, random_seed=RANDOM_SEED, compute_convergence_checks=False
        )
        idatas_50.append(idata)
        bart_rvs_50.append(μ_)
# Out:
# Multiprocess sampling (4 chains in 4 jobs)
# CompoundStep
# >NUTS: [α]
# >PGBART: [μ_]
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# Sampling 4 chains for 1_000 tune and 1_000 draw iterations (4_000 + 4_000 draws total) took 27 seconds.
# Multiprocess sampling (4 chains in 4 jobs)
# CompoundStep
# >NUTS: [α]
# >PGBART: [μ_]
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# Sampling 4 chains for 1_000 tune and 1_000 draw iterations (4_000 + 4_000 draws total) took 25 seconds.
# Multiprocess sampling (4 chains in 4 jobs)
# CompoundStep
# >NUTS: [α]
# >PGBART: [μ_]
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# Sampling 4 chains for 1_000 tune and 1_000 draw iterations (4_000 + 4_000 draws total) took 26 seconds.
# Multiprocess sampling (4 chains in 4 jobs)
# CompoundStep
# >NUTS: [α]
# >PGBART: [μ_]
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# Sampling 4 chains for 1_000 tune and 1_000 draw iterations (4_000 + 4_000 draws total) took 27 seconds.
# Multiprocess sampling (4 chains in 4 jobs)
# CompoundStep
# >NUTS: [α]
# >PGBART: [μ_]
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# Sampling 4 chains for 1_000 tune and 1_000 draw iterations (4_000 + 4_000 draws total) took 27 seconds.
# Multiprocess sampling (4 chains in 4 jobs)
# CompoundStep
# >NUTS: [α]
# >PGBART: [μ_]
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# Sampling 4 chains for 1_000 tune and 1_000 draw iterations (4_000 + 4_000 draws total) took 27 seconds.
# Multiprocess sampling (4 chains in 4 jobs)
# CompoundStep
# >NUTS: [α]
# >PGBART: [μ_]
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# Sampling 4 chains for 1_000 tune and 1_000 draw iterations (4_000 + 4_000 draws total) took 27 seconds.
# Multiprocess sampling (4 chains in 4 jobs)
# CompoundStep
# >NUTS: [α]
# >PGBART: [μ_]
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# Sampling 4 chains for 1_000 tune and 1_000 draw iterations (4_000 + 4_000 draws total) took 28 seconds.
# Multiprocess sampling (4 chains in 4 jobs)
# CompoundStep
# >NUTS: [α]
# >PGBART: [μ_]
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# Sampling 4 chains for 1_000 tune and 1_000 draw iterations (4_000 + 4_000 draws total) took 27 seconds.
# Multiprocess sampling (4 chains in 4 jobs)
# CompoundStep
# >NUTS: [α]
# >PGBART: [μ_]
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# Sampling 4 chains for 1_000 tune and 1_000 draw iterations (4_000 + 4_000 draws total) took 28 seconds.
# Multiprocess sampling (4 chains in 4 jobs)
# CompoundStep
# >NUTS: [α]
# >PGBART: [μ_]
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# Sampling 4 chains for 1_000 tune and 1_000 draw iterations (4_000 + 4_000 draws total) took 27 seconds.
# Multiprocess sampling (4 chains in 4 jobs)
# CompoundStep
# >NUTS: [α]
# >PGBART: [μ_]
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# Sampling 4 chains for 1_000 tune and 1_000 draw iterations (4_000 + 4_000 draws total) took 28 seconds.
# Multiprocess sampling (4 chains in 4 jobs)
# CompoundStep
# >NUTS: [α]
# >PGBART: [μ_]
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# Sampling 4 chains for 1_000 tune and 1_000 draw iterations (4_000 + 4_000 draws total) took 27 seconds.

# %%
ax = vi_evi(
    bart_rvs_50,
    idatas_50,
    X,
    vi_results_50["indices"],
    "VI",
    100,
    RANDOM_SEED,
    figsize=(10, 5),
)
ax.set_title("Boston, m=50, method=VI")
plt.savefig("boston_m50_vi.png");

# %% [markdown]
# ## Explicit computation of R² following method="backward" order, with m=50

# %%
idatas_50 = []
bart_rvs_50 = []

for idx in range(X.shape[1]):
    with pm.Model() as model:
        α = pm.Exponential("α", 0.1)
        μ_ = pmb.BART(
            "μ_", X.iloc[:, bw_results_50["indices"][: idx + 1]], np.log(Y), m=50
        )
        μ = pm.Deterministic("μ", np.exp(μ_))
        y = pm.NegativeBinomial("y", mu=μ, alpha=α, observed=Y)
        idata = pm.sample(
            chains=4, random_seed=RANDOM_SEED, compute_convergence_checks=False
        )
        idatas_50.append(idata)
        bart_rvs_50.append(μ_)
# Out:
# Multiprocess sampling (4 chains in 4 jobs)
# CompoundStep
# >NUTS: [α]
# >PGBART: [μ_]
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# Sampling 4 chains for 1_000 tune and 1_000 draw iterations (4_000 + 4_000 draws total) took 29 seconds.
# Multiprocess sampling (4 chains in 4 jobs)
# CompoundStep
# >NUTS: [α]
# >PGBART: [μ_]
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# Sampling 4 chains for 1_000 tune and 1_000 draw iterations (4_000 + 4_000 draws total) took 27 seconds.
# Multiprocess sampling (4 chains in 4 jobs)
# CompoundStep
# >NUTS: [α]
# >PGBART: [μ_]
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# Sampling 4 chains for 1_000 tune and 1_000 draw iterations (4_000 + 4_000 draws total) took 27 seconds.
# Multiprocess sampling (4 chains in 4 jobs)
# CompoundStep
# >NUTS: [α]
# >PGBART: [μ_]
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# Sampling 4 chains for 1_000 tune and 1_000 draw iterations (4_000 + 4_000 draws total) took 27 seconds.
# Multiprocess sampling (4 chains in 4 jobs)
# CompoundStep
# >NUTS: [α]
# >PGBART: [μ_]
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# Sampling 4 chains for 1_000 tune and 1_000 draw iterations (4_000 + 4_000 draws total) took 29 seconds.
# Multiprocess sampling (4 chains in 4 jobs)
# CompoundStep
# >NUTS: [α]
# >PGBART: [μ_]
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# Sampling 4 chains for 1_000 tune and 1_000 draw iterations (4_000 + 4_000 draws total) took 28 seconds.
# Multiprocess sampling (4 chains in 4 jobs)
# CompoundStep
# >NUTS: [α]
# >PGBART: [μ_]
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# Sampling 4 chains for 1_000 tune and 1_000 draw iterations (4_000 + 4_000 draws total) took 27 seconds.
# Multiprocess sampling (4 chains in 4 jobs)
# CompoundStep
# >NUTS: [α]
# >PGBART: [μ_]
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# Sampling 4 chains for 1_000 tune and 1_000 draw iterations (4_000 + 4_000 draws total) took 27 seconds.
# Multiprocess sampling (4 chains in 4 jobs)
# CompoundStep
# >NUTS: [α]
# >PGBART: [μ_]
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# Sampling 4 chains for 1_000 tune and 1_000 draw iterations (4_000 + 4_000 draws total) took 26 seconds.
# Multiprocess sampling (4 chains in 4 jobs)
# CompoundStep
# >NUTS: [α]
# >PGBART: [μ_]
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# Sampling 4 chains for 1_000 tune and 1_000 draw iterations (4_000 + 4_000 draws total) took 28 seconds.
# Multiprocess sampling (4 chains in 4 jobs)
# CompoundStep
# >NUTS: [α]
# >PGBART: [μ_]
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# Sampling 4 chains for 1_000 tune and 1_000 draw iterations (4_000 + 4_000 draws total) took 27 seconds.
# Multiprocess sampling (4 chains in 4 jobs)
# CompoundStep
# >NUTS: [α]
# >PGBART: [μ_]
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# Sampling 4 chains for 1_000 tune and 1_000 draw iterations (4_000 + 4_000 draws total) took 27 seconds.
# Multiprocess sampling (4 chains in 4 jobs)
# CompoundStep
# >NUTS: [α]
# >PGBART: [μ_]
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# Sampling 4 chains for 1_000 tune and 1_000 draw iterations (4_000 + 4_000 draws total) took 29 seconds.

# %%
ax = vi_evi(
    bart_rvs_50,
    idatas_50,
    X,
    bw_results_50["indices"],
    "backward",
    100,
    RANDOM_SEED,
    figsize=(10, 5),
)
ax.set_title("Boston, m=50, method=backward")
plt.savefig("boston_m50_bw.png");

# %% [markdown]
# ## Explicit computation of R² following method="VI" order, with m=200
#
# First run to get the ranking of the variable importance with `m=200`.

# %%
with pm.Model() as model:
    α = pm.Exponential("α", 0.1)
    μ_ = pmb.BART("μ_", X, np.log(Y), m=200)
    μ = pm.Deterministic("μ", np.exp(μ_))
    y = pm.NegativeBinomial("y", mu=μ, alpha=α, observed=Y)
    idata_200 = pm.sample(
        chains=4,
        random_seed=RANDOM_SEED,
    )
# Out:
# Multiprocess sampling (4 chains in 4 jobs)
# CompoundStep
# >NUTS: [α]
# >PGBART: [μ_]
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# Sampling 4 chains for 1_000 tune and 1_000 draw iterations (4_000 + 4_000 draws total) took 97 seconds.
# The rhat statistic is larger than 1.01 for some parameters. This indicates problems during sampling. See https://arxiv.org/abs/1903.08008 for details
# The effective sample size per chain is smaller than 100 for some parameters.  A higher number is needed for reliable rhat and ess computation. See https://arxiv.org/abs/1903.08008 for details

# %%
vi_results_200 = pmb.compute_variable_importance(
    idata_200, μ_, X, method="VI", random_seed=RANDOM_SEED
)
bw_results_200 = pmb.compute_variable_importance(
    idata_200, μ_, X, method="backward", random_seed=RANDOM_SEED
)

# %%
_, axes = plt.subplots(1, 2, figsize=(12, 4))

pmb.plot_variable_importance(vi_results_200, figsize=(12, 5), ax=axes[0])
axes[0].set_title("VI")
axes[0].set_xticklabels(axes[0].get_xticklabels(), rotation=45, ha="right", fontsize=11)

pmb.plot_variable_importance(bw_results_200, figsize=(12, 5), ax=axes[1])
axes[1].set_title("backward")
axes[1].set_xticklabels(
    axes[1].get_xticklabels(), rotation=45, ha="right", fontsize=11
);

# %%
_, ax = pmb.plot_variable_inclusion(idata_200, X, figsize=(12, 5))
ax.set_title("Normalized variable inclusion", fontsize=16)
ax.set_xticklabels(ax.get_xticklabels(), rotation=45, ha="right", fontsize=12)
ax.set_yticklabels(ax.get_yticklabels(), rotation=45, ha="right", fontsize=11);
# Out:
# /var/folders/m_/brf3tky55f3gf6dy8w7c6s0w0000gn/T/ipykernel_22826/4157930357.py:4: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_yticklabels(ax.get_yticklabels(), rotation=45, ha="right", fontsize=11);

# %%
axes = pmb.plot_scatter_submodels(vi_results_200, np.exp, figsize=(12, 10), grid=(4, 3))
plt.suptitle("Comparison of submodels' predictions to full model's", fontsize=16)
plt.tight_layout();
# Out:
# /Users/alex_andorra/mambaforge/envs/bart-variables/lib/python3.10/site-packages/pymc_bart/utils.py:519: UserWarning: The grid is smaller than the number of available variables to plot.
#                 Automatically adjusting the grid size.
#   warnings.warn(
# /var/folders/m_/brf3tky55f3gf6dy8w7c6s0w0000gn/T/ipykernel_22826/724910099.py:3: UserWarning: The figure layout has changed to tight
#   plt.tight_layout();

# %%
idatas_200 = []
bart_rvs_200 = []

for idx in range(X.shape[1]):
    with pm.Model() as model:
        α = pm.Exponential("α", 0.1)
        μ_ = pmb.BART(
            "μ_", X.iloc[:, vi_results_200["indices"][: idx + 1]], np.log(Y), m=200
        )
        μ = pm.Deterministic("μ", np.exp(μ_))
        y = pm.NegativeBinomial("y", mu=μ, alpha=α, observed=Y)
        idata = pm.sample(
            chains=4, random_seed=RANDOM_SEED, compute_convergence_checks=False
        )
        idatas_200.append(idata)
        bart_rvs_200.append(μ_)
# Out:
# Multiprocess sampling (4 chains in 4 jobs)
# CompoundStep
# >NUTS: [α]
# >PGBART: [μ_]
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# Sampling 4 chains for 1_000 tune and 1_000 draw iterations (4_000 + 4_000 draws total) took 130 seconds.
# Multiprocess sampling (4 chains in 4 jobs)
# CompoundStep
# >NUTS: [α]
# >PGBART: [μ_]
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# Sampling 4 chains for 1_000 tune and 1_000 draw iterations (4_000 + 4_000 draws total) took 131 seconds.
# Multiprocess sampling (4 chains in 4 jobs)
# CompoundStep
# >NUTS: [α]
# >PGBART: [μ_]
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# Sampling 4 chains for 1_000 tune and 1_000 draw iterations (4_000 + 4_000 draws total) took 127 seconds.
# Multiprocess sampling (4 chains in 4 jobs)
# CompoundStep
# >NUTS: [α]
# >PGBART: [μ_]
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# Sampling 4 chains for 1_000 tune and 1_000 draw iterations (4_000 + 4_000 draws total) took 139 seconds.
# Multiprocess sampling (4 chains in 4 jobs)
# CompoundStep
# >NUTS: [α]
# >PGBART: [μ_]
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# Sampling 4 chains for 1_000 tune and 1_000 draw iterations (4_000 + 4_000 draws total) took 129 seconds.
# Multiprocess sampling (4 chains in 4 jobs)
# CompoundStep
# >NUTS: [α]
# >PGBART: [μ_]
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# Sampling 4 chains for 1_000 tune and 1_000 draw iterations (4_000 + 4_000 draws total) took 129 seconds.
# Multiprocess sampling (4 chains in 4 jobs)
# CompoundStep
# >NUTS: [α]
# >PGBART: [μ_]
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# Sampling 4 chains for 1_000 tune and 1_000 draw iterations (4_000 + 4_000 draws total) took 152 seconds.
# Multiprocess sampling (4 chains in 4 jobs)
# CompoundStep
# >NUTS: [α]
# >PGBART: [μ_]
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# Sampling 4 chains for 1_000 tune and 1_000 draw iterations (4_000 + 4_000 draws total) took 139 seconds.
# Multiprocess sampling (4 chains in 4 jobs)
# CompoundStep
# >NUTS: [α]
# >PGBART: [μ_]
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# Sampling 4 chains for 1_000 tune and 1_000 draw iterations (4_000 + 4_000 draws total) took 155 seconds.
# Multiprocess sampling (4 chains in 4 jobs)
# CompoundStep
# >NUTS: [α]
# >PGBART: [μ_]
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# Sampling 4 chains for 1_000 tune and 1_000 draw iterations (4_000 + 4_000 draws total) took 156 seconds.
# Multiprocess sampling (4 chains in 4 jobs)
# CompoundStep
# >NUTS: [α]
# >PGBART: [μ_]
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# Sampling 4 chains for 1_000 tune and 1_000 draw iterations (4_000 + 4_000 draws total) took 141 seconds.
# Multiprocess sampling (4 chains in 4 jobs)
# CompoundStep
# >NUTS: [α]
# >PGBART: [μ_]
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# Sampling 4 chains for 1_000 tune and 1_000 draw iterations (4_000 + 4_000 draws total) took 142 seconds.
# Multiprocess sampling (4 chains in 4 jobs)
# CompoundStep
# >NUTS: [α]
# >PGBART: [μ_]
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# Sampling 4 chains for 1_000 tune and 1_000 draw iterations (4_000 + 4_000 draws total) took 131 seconds.

# %%
ax = vi_evi(
    bart_rvs_200,
    idatas_200,
    X,
    vi_results_200["indices"],
    "VI",
    100,
    RANDOM_SEED,
    figsize=(10, 5),
)
ax.set_title("Boston, m=200, method=VI")
plt.savefig("boston_m200_vi.png")

# %% [markdown]
# ## Explicit computation of R² following method="backward" order, with m=200

# %%
idatas_200 = []
bart_rvs_200 = []

for idx in range(X.shape[1]):
    with pm.Model() as model:
        α = pm.Exponential("α", 0.1)
        μ_ = pmb.BART(
            "μ_", X.iloc[:, bw_results_200["indices"][: idx + 1]], np.log(Y), m=200
        )
        μ = pm.Deterministic("μ", np.exp(μ_))
        y = pm.NegativeBinomial("y", mu=μ, alpha=α, observed=Y)
        idata = pm.sample(
            chains=4, random_seed=RANDOM_SEED, compute_convergence_checks=False
        )
        idatas_200.append(idata)
        bart_rvs_200.append(μ_)
# Out:
# Multiprocess sampling (4 chains in 4 jobs)
# CompoundStep
# >NUTS: [α]
# >PGBART: [μ_]
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# Sampling 4 chains for 1_000 tune and 1_000 draw iterations (4_000 + 4_000 draws total) took 129 seconds.
# Multiprocess sampling (4 chains in 4 jobs)
# CompoundStep
# >NUTS: [α]
# >PGBART: [μ_]
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# Sampling 4 chains for 1_000 tune and 1_000 draw iterations (4_000 + 4_000 draws total) took 126 seconds.
# Multiprocess sampling (4 chains in 4 jobs)
# CompoundStep
# >NUTS: [α]
# >PGBART: [μ_]
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# Sampling 4 chains for 1_000 tune and 1_000 draw iterations (4_000 + 4_000 draws total) took 126 seconds.
# Multiprocess sampling (4 chains in 4 jobs)
# CompoundStep
# >NUTS: [α]
# >PGBART: [μ_]
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# Sampling 4 chains for 1_000 tune and 1_000 draw iterations (4_000 + 4_000 draws total) took 137 seconds.
# Multiprocess sampling (4 chains in 4 jobs)
# CompoundStep
# >NUTS: [α]
# >PGBART: [μ_]
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# Sampling 4 chains for 1_000 tune and 1_000 draw iterations (4_000 + 4_000 draws total) took 139 seconds.
# Multiprocess sampling (4 chains in 4 jobs)
# CompoundStep
# >NUTS: [α]
# >PGBART: [μ_]
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# Sampling 4 chains for 1_000 tune and 1_000 draw iterations (4_000 + 4_000 draws total) took 130 seconds.
# Multiprocess sampling (4 chains in 4 jobs)
# CompoundStep
# >NUTS: [α]
# >PGBART: [μ_]
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# Sampling 4 chains for 1_000 tune and 1_000 draw iterations (4_000 + 4_000 draws total) took 131 seconds.
# Multiprocess sampling (4 chains in 4 jobs)
# CompoundStep
# >NUTS: [α]
# >PGBART: [μ_]
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# Sampling 4 chains for 1_000 tune and 1_000 draw iterations (4_000 + 4_000 draws total) took 129 seconds.
# Multiprocess sampling (4 chains in 4 jobs)
# CompoundStep
# >NUTS: [α]
# >PGBART: [μ_]
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# Sampling 4 chains for 1_000 tune and 1_000 draw iterations (4_000 + 4_000 draws total) took 134 seconds.
# Multiprocess sampling (4 chains in 4 jobs)
# CompoundStep
# >NUTS: [α]
# >PGBART: [μ_]
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# Sampling 4 chains for 1_000 tune and 1_000 draw iterations (4_000 + 4_000 draws total) took 130 seconds.
# Multiprocess sampling (4 chains in 4 jobs)
# CompoundStep
# >NUTS: [α]
# >PGBART: [μ_]
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# Sampling 4 chains for 1_000 tune and 1_000 draw iterations (4_000 + 4_000 draws total) took 150 seconds.
# Multiprocess sampling (4 chains in 4 jobs)
# CompoundStep
# >NUTS: [α]
# >PGBART: [μ_]
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# Sampling 4 chains for 1_000 tune and 1_000 draw iterations (4_000 + 4_000 draws total) took 154 seconds.
# Multiprocess sampling (4 chains in 4 jobs)
# CompoundStep
# >NUTS: [α]
# >PGBART: [μ_]
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# Sampling 4 chains for 1_000 tune and 1_000 draw iterations (4_000 + 4_000 draws total) took 153 seconds.

# %%
ax = vi_evi(
    bart_rvs_200,
    idatas_200,
    X,
    bw_results_200["indices"],
    "backward",
    100,
    RANDOM_SEED,
    figsize=(10, 5),
)
ax.set_title("Boston, m=200, method=backward")
plt.savefig("boston_m200_bw.png");
